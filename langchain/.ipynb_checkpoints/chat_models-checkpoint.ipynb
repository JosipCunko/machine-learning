# %% [markdown]
# - types of messages langchain offers
# - prompt templates
# - chains

# %%
from langchain_openai.chat_models import ChatOpenAI
import sys
sys.path.append("..")
import config

chat = ChatOpenAI(
    model = "openai/gpt-4",
    seed = 365,
    api_key=config.apiKey2,
    temperature = 0,
    base_url="https://openrouter.ai/api/v1"
)

# %%
res = chat.invoke(""" Can you briefly explain what is an oscilloscope? """) # more usecases in LCEL

# %%
res
# Out:
# AIMessage(content='An oscilloscope is a type of electronic test instrument that allows observation of varying signal voltages, usually as a two-dimensional plot of one or more signals as a function of time. It is commonly used to observe the exact wave shape of an electrical signal. In addition to the amplitude of the signal, the oscilloscope can show distortion, the time between two events (such as pulse width, period, or rise time) and relative timing of two related signals.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 94, 'prompt_tokens': 19, 'total_tokens': 113, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'cost': 0.00621, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 0.00621, 'upstream_inference_prompt_cost': 0.00057, 'upstream_inference_completions_cost': 0.00564}}, 'model_provider': 'openai', 'model_name': 'openai/gpt-4', 'system_fingerprint': None, 'id': 'gen-1771077596-J6HEZwOlWSSUBabgLRnI', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c5c73-9e60-7e20-90f4-8928b2141a46-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 94, 'total_tokens': 113, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# #### System and human messages

# %%
from langchain_core.messages import SystemMessage, HumanMessage

# %%
messageS = SystemMessage(content = """You are an chatbot as a creative programmer with a lot of experience in game dev, 
web dev and data science that answers questions with a wish to improve the questioner.""")
messageH = HumanMessage(content = "Recently I've been interested in game development. Can you suggest some begginer projects in Unity?")

# %%
res = chat.invoke([messageS, messageH])

# %%
res
# Out:
# AIMessage(content="Absolutely, I'm glad to hear about your interest in game development. Unity is a great platform to start with. Here are a few beginner-friendly project ideas:\n\n1. **2D Platformer Game**: This is a classic genre, think of games like Super Mario. You'll learn about character controls, physics, level design, and enemy AI.\n\n2. **Endless Runner**: Think of games like Temple Run or Flappy Bird. These games are simple yet addictive. You'll learn about spawning obstacles, character controls, and implementing a scoring system.\n\n3. **Space Invaders Clone**: This will help you understand the basics of enemy AI, shooting mechanics, and implementing lives and scoring systems.\n\n4. **Puzzle Game**: You could create a simple match-3 game (like Candy Crush) or a sliding puzzle game. This will help you understand game logic and state management.\n\n5. **Simple RPG (Role Playing Game)**: Create a small world where a player can move around, interact with NPCs (Non-Player Characters), and complete quests. This is a bit more complex but will introduce you to dialogue systems, inventory systems, and basic combat mechanics.\n\n6. **Virtual Pet Game**: Think of games like Tamagotchi. You'll learn about game states, saving and loading data, and more.\n\nRemember, the goal of these projects is not just to create a game, but to learn the principles of game development. Start small, gradually increase the complexity of your projects, and most importantly, have fun in the process. Happy coding!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 314, 'prompt_tokens': 67, 'total_tokens': 381, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'cost': 0.02085, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 0.02085, 'upstream_inference_prompt_cost': 0.00201, 'upstream_inference_completions_cost': 0.01884}}, 'model_provider': 'openai', 'model_name': 'openai/gpt-4', 'system_fingerprint': None, 'id': 'gen-1771078358-TZH86jT0caeOoxzf9nbH', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c5c7f-3f8c-7823-8d31-c697a8358e3b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 67, 'output_tokens': 314, 'total_tokens': 381, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
print(res.content)
# Out:
# Absolutely, I'm glad to hear about your interest in game development. Unity is a great platform to start with. Here are a few beginner-friendly project ideas:
#
# 1. **2D Platformer Game**: This is a classic genre, think of games like Super Mario. You'll learn about character controls, physics, level design, and enemy AI.
#
# 2. **Endless Runner**: Think of games like Temple Run or Flappy Bird. These games are simple yet addictive. You'll learn about spawning obstacles, character controls, and implementing a scoring system.
#
# 3. **Space Invaders Clone**: This will help you understand the basics of enemy AI, shooting mechanics, and implementing lives and scoring systems.
#
# 4. **Puzzle Game**: You could create a simple match-3 game (like Candy Crush) or a sliding puzzle game. This will help you understand game logic and state management.
#
# 5. **Simple RPG (Role Playing Game)**: Create a small world where a player can move around, interact with NPCs (Non-Player Characters), and complete quests. This is a bit more complex but will introduce you to dialogue systems, inventory systems, and basic combat mechanics.
#
# 6. **Virtual Pet Game**: Think of games like Tamagotchi. You'll learn about game states, saving and loading data, and more.
#
# Remember, the goal of these projects is not just to create a game, but to learn the principles of game development. Start small, gradually increase the complexity of your projects, and most importantly, have fun in the process. Happy coding!
